# %%
import os
import shutil
os.environ['OPENAI_API_KEY'] = "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"

# %%
wget https://raw.githubusercontent.com/run-llama/llama_index/main/examples/paul_graham_essay/data/paul_graham_essay.txt
os.mkdir('data')
shutil.copyfile('/content/paul_graham_essay.txt', '/content/data/paul_graham_essay.txt')
# Out:
#   Cell In[8], line 1
#     wget https://raw.githubusercontent.com/run-llama/llama_index/main/examples/paul_graham_essay/data/paul_graham_essay.txt
#          ^
# SyntaxError: invalid syntax

# %%
# !python starter.py
# Out:
# using existing context
# DEBUG:llama_index.storage.kvstore.simple_kvstore:Loading llama_index.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# Loading llama_index.storage.kvstore.simple_kvstore from ./storage\docstore.json.
# DEBUG:fsspec.local:open file: c:/Users/Varang Rai/Desktop/llma_basics/storage/docstore.json
# open file: c:/Users/Varang Rai/Desktop/llma_basics/storage/docstore.json
# DEBUG:llama_index.storage.kvstore.simple_kvstore:Loading llama_index.storage.kvstore.simple_kvstore from ./storage\index_store.json.
# Loading llama_index.storage.kvstore.simple_kvstore from ./storage\index_store.json.
# DEBUG:fsspec.local:open file: c:/Users/Varang Rai/Desktop/llma_basics/storage/index_store.json
# open file: c:/Users/Varang Rai/Desktop/llma_basics/storage/index_store.json
# DEBUG:llama_index.vector_stores.simple:Loading llama_index.vector_stores.simple from ./storage\vector_store.json.
# Loading llama_index.vector_stores.simple from ./storage\vector_store.json.
# ...
